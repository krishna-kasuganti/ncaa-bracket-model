# %% [markdown]
# # NCAA Bracket Model — Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 100)

# %%
teams = pd.read_csv("../data/raw/MTeams.csv")
teams.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2025
# 1    1102    Air Force           1985          2025
# 2    1103        Akron           1985          2025
# 3    1104      Alabama           1985          2025
# 4    1105  Alabama A&M           2000          2025

# %%
season_stats = pd.read_csv("../data/raw/MRegularSeasonDetailedResults.csv")
season_stats.tail()
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 118877    2025     132     1196      86     1397      77    N      0    26
# 118878    2025     132     1272      84     1412      72    N      0    32
# 118879    2025     132     1276      59     1458      53    N      0    19
# 118880    2025     132     1433      68     1206      63    N      0    19
# 118881    2025     132     1463      90     1165      84    N      0    31
#
#         WFGA  ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 118877    61  ...     26    25    32    5   20    15    9     7     5   21
# 118878    68  ...     27    17    23   21   23    10   15     5     4   21
# 118879    59  ...     39    16    18   15   31     8    6     3     2   14
# 118880    47  ...     21    16    19   14   19    13   11    11     3   22
# 118881    62  ...     27    15    16    4   26    15   11     2     2   16
#
# [5 rows x 34 columns]

# %%
seeds = pd.read_csv("../data/raw/MNCAATourneySeeds.csv")
seeds.tail()
# Out:
#       Season Seed  TeamID
# 2621    2025  Z12    1161
# 2622    2025  Z13    1213
# 2623    2025  Z14    1423
# 2624    2025  Z15    1303
# 2625    2025  Z16    1313

# %%
seasons = pd.read_csv("../data/raw/MSeasons.csv")
seasons.tail()
# Out:
#     Season     DayZero RegionW  RegionX  RegionY RegionZ
# 36    2021  11/02/2020    East     West  Midwest   South
# 37    2022  11/01/2021    East     West  Midwest   South
# 38    2023  10/31/2022    East    South  Midwest    West
# 39    2024  11/06/2023    East     West  Midwest   South
# 40    2025  11/04/2024    East  Midwest    South    West

# %%
massey = pd.read_csv("../data/raw/MMasseyOrdinals.csv")
massey.tail()
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 5565788    2025            133        WOL    1476          299
# 5565789    2025            133        WOL    1477          341
# 5565790    2025            133        WOL    1478          335
# 5565791    2025            133        WOL    1479          303
# 5565792    2025            133        WOL    1480          342

# %%
unique_seasons = massey[massey['RankingDayNum'] <= 133].groupby("SystemName")["Season"].nunique()
unique_seasons[unique_seasons >= 21].sort_values(ascending=False)
# Out:
# SystemName
# AP     23
# COL    23
# DOL    23
# MOR    23
# POM    23
# USA    23
# WLK    23
# BIH    22
# RTH    22
# WOL    22
# DUN    21
# SAG    21
# SEL    21
# Name: Season, dtype: int64

# %%
massey[massey['Season'] == 2023].groupby('SystemName')['TeamID'].nunique().sort_values(ascending=True)
# Out:
# SystemName
# DES     45
# USA     49
# AP      52
# ESR     59
# 7OT    363
# RTH    363
# RT     363
# RPI    363
# RMS    363
# RME    363
# POM    363
# PIR    363
# PGH    363
# OMN    363
# NOL    363
# NET    363
# REW    363
# RTP    363
# SAG    363
# MOR    363
# SEL    363
# SFX    363
# SMS    363
# SPR    363
# SRS    363
# STH    363
# STY    363
# TPR    363
# TRK    363
# TRP    363
# WIL    363
# WLK    363
# WMV    363
# RWP    363
# MMG    363
# MAS    363
# WOB    363
# ARG    363
# ATP    363
# BAR    363
# BBT    363
# BIH    363
# BNZ    363
# BWE    363
# CBR    363
# COL    363
# DAV    363
# DCI    363
# DII    363
# DOK    363
# DOL    363
# DUN    363
# EBP    363
# EMK    363
# FAS    363
# HAS    363
# INC    363
# JJK    363
# JNG    363
# KCX    363
# KLK    363
# KPK    363
# KRA    363
# LAW    363
# LMC    363
# LOG    363
# MB     363
# WOL    363
# Name: TeamID, dtype: int64

# %%
tourney_results = pd.read_csv("../data/raw/MNCAATourneyCompactResults.csv")
tourney_results.tail()
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 2513    2024     146     1301      76     1181      64    N      0
# 2514    2024     146     1345      72     1397      66    N      0
# 2515    2024     152     1163      86     1104      72    N      0
# 2516    2024     152     1345      63     1301      50    N      0
# 2517    2024     154     1163      75     1345      60    N      0
